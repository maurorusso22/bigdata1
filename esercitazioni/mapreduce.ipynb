# %% [markdown]
# # Simulazione Hadoop Streaming con le pipe di UNIX

# %% [markdown]
# Trova la temperatura massima per anno

# %%
# !cat /content/drive/MyDrive/data/temperature/* | \
    python /content/drive/MyDrive/mapreduce/max_temp_mapper.py | \
    sort | \
    python /content/drive/MyDrive/mapreduce/max_temp_reducer.py > \
    /content/drive/MyDrive/output/max_temp.txt

# %%
# !cat /content/drive/MyDrive/output/max_temp.txt

# %% [markdown]
# Conta le parole in un insieme di documenti

# %%
# !cat /content/drive/MyDrive/data/wikipedia/* | \
    python /content/drive/MyDrive/mapreduce/wordcount_mapper.py | \
    sort | \
    python /content/drive/MyDrive/mapreduce/wordcount_reducer.py > \
    /content/drive/MyDrive/output/wordcount.txt

# %%
# !cat /content/drive/MyDrive/output/wordcount.txt
